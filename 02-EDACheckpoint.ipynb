# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
#
# **Pranava Gande** - Conceptualization, Data Curation, Background research
#
# **Sinai Brito** - Visualization, Analysis
#
# **Alexa Covarrubias** - Visualization, Analysis
#
# **Jenna Cheng** - Writing - Original Draft
#
# **Monique Ramirez** - Writing - Original Draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# This project is about U.S. adults from the 2017-2018 National Health and Nutrition Examination Survey (NHANES) who meet the biomarker criteria for diabetes (either from tests of hemoglobin A1c or fasting plasma glucose).
#
# This project asks three related questions:
#
# 1. Which non-clinical variables – namely, sex, race, ethnicity, education, income, health insurance, source of care, time since previous routine health check-up, exercise, smoking, and alcohol usage – are associated with remaining undiagnosed?
#
# 2. How well can we predict whether a person is aware of their diabetes (i.e. undiagnosed vs diagnosed) using these non-clinical variables, and which of these variables has highest feature importance?
#
# 3. Does classification performance differ across race, ethnicity, or income, thereby challenging the equity of non-laboratory screening models?
#
# This project will elucidate these questions using survey-weighted logistic regression and supervised classification models.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Diabetes is among the most common chronic conditions in the United States, and it is a leading driver of illness, disability, and healthcare spending.[[1]](#ref1)[[2]](#ref2) According to CDC estimates, tens of millions of U.S. adults have diabetes, with roughly a quarter being unaware [[1]](#ref1). High blood sugar can remain asymptomatic while causing insidious health effects.[[3]](#ref3) Thus, people who remain undiagnosed, due to not adhering to routine health checkups for example, may only first show up with complications, including cardiovascular disease, kidney disease, or ocular damage.[[3]](#ref3)[[4]](#ref4) This makes early detection of diabetes critical.[[4]](#ref4)
#
# NHANES is a nationally representative cross-sectional survey that provides interviews, physical exam results, and laboratory test data from the U.S. population.[[5]](#ref5) It is the among the main data sources used to monitor the incidence and burden of diabetes, both diagnosed and undiagnosed, at population-scale.[[1]](#ref1)[[5]](#ref5)[[6]](#ref6) For each participant, it documents whether a physician has diagnosed diabetes as well as lab biomarker (hemoglobin A1c and fasting plasma glucose) results.[[5]](#ref5)[[6]](#ref6) This wealth of data has resulted in many important recent epidemiological findings.[[1]](#ref1)[[6]](#ref6) This includes documenting healthcare inequities; namely, Black, Hispanic, and Asian adults have a higher prevalence of both diagnosed and undiagnosed diabetes than non-Hispanic White adults.[[6]](#ref6) In addition, participants with lower education levels were also found to have higher rates of undiagnosed diabetes.[[6]](#ref6) These findings indicate that there are broader inequities in which people are likely to be made aware of their diabetes via formal diagnosis.[[3]](#ref3)[[6]](#ref6)[[7]](#ref7)
#
# There have been a few studies that have linked other non-clinical variables to diabetes diagnosis. These include variables that are not be related to healthcare equity. For example, Wilder et al. showed that obesity was linked to un NHANES III (1988-1994).[[8]](#ref8) In the Korean NHANES (KNHANES 2008-2011), a replica of the NHANES dataset at a national scale in Korea, it was found that cardiometabolic risk factors like hypertension and dyslipidemia were also linked to undiagnosed diabetes.[[9]](#ref9) Thus, undiagnosed diabetes is affected by the interplay of numerous different social and medical factors, which can be difficult to disentangle despite the high stakes.[[3]](#ref3)[[4]](#ref4)[[8]](#ref8)[[9]](#ref9) This makes this problem an ideal candidate for data science approaches.
#
# There is a growing line of work that aims to do exactly this, i.e. detect undiagnosed diabetes solely from easily measured variables.[[10]](#ref10)[[11]](#ref11) A recent study in JMIR AI trained a model to NHANES 1999-2000 that used demographics, anthropometric measures, health behaviors and some other clinical variables.[[10]](#ref10) This model achieved an AUC of 0.91 in the task of classifying adults with undiagnosed diabetes and healthy adults.[[10]](#ref10) For comparison, an AUC of above 0.8 is generally considered clinically usable for medical diagnostic models.[[13]](#ref13) Another paper by Riveros Perez and Avella-Molano reported that XGBoost achieved an AUC of 0.82 on the same task using only lifestyle and anthropometric measurements in NHANES 2007-2008.[[11]](#ref11) These studies are promising results that suggest that data science models might support early risk screening for diabetes.[[10]](#ref10)[[11]](#ref11)
#
# Our project is also a predictive-modelling task, but otherwise differs from previous studies in the field.[[10]](#ref10)[[11]](#ref11) We focus on a different population – adults in NHANES 2017-2018 who already meet biomarker criteria for diabetes.[[5]](#ref5)[[6]](#ref6)[[12]](#ref12) In this group, we aim to model awareness of diabetes status and discover the features that are most explain this awareness gap.[[4]](#ref4)[[7]](#ref7) As such, our work builds on previous NHANES studies of undiagnosed diabetes.[[4]](#ref4)[[8]](#ref8)[[9]](#ref9)[[10]](#ref10)[[11]](#ref11) Prior results are taken a step further by applying a novel predictive model to discover who among those with diabetes remain undiagnosed.[[10]](#ref10)[[11]](#ref11) These results will also shed light on equity-related questions to understand how diabetes screening models may contend with different demographic groups.[[3]](#ref3)[[6]](#ref6)[[7]](#ref7)
#
# <a id="ref1"></a>[1] Centers for Disease Control and Prevention. *National Diabetes Statistics Report.* Atlanta, GA: U.S. Department of Health and Human Services. Available at: https://www.cdc.gov/diabetes/php/data-research/
#
# <a id="ref2"></a>[2] American Diabetes Association. *Economic Costs of Diabetes in the U.S. in 2017.* Diabetes Care. 2018;41(5):917–928. PubMed: https://pubmed.ncbi.nlm.nih.gov/29567642/
#
# <a id="ref3"></a>[3] Mayo Clinic. *Hyperglycemia in diabetes – Symptoms and causes.* Available at: https://www.mayoclinic.org/diseases-conditions/hyperglycemia/symptoms-causes/syc-20373631
#
# <a id="ref4"></a>[4] Centers for Disease Control and Prevention. *How Diabetes Can Affect Your Body.* Infographic. Available at: https://www.cdc.gov/diabetes/communication-resources/how-diabetes-can-affect-your-body.html
#
# <a id="ref5"></a>[5] National Center for Health Statistics. *National Health and Nutrition Examination Survey (NHANES) – Overview and Methods.* Available at: https://www.cdc.gov/nchs/hus/sources-definitions/nhanes.htm
#
# <a id="ref6"></a>[6] Centers for Disease Control and Prevention. *Appendix A: Detailed Tables for the National Diabetes Statistics Report (2017–2020).* Table 1: Age-adjusted prevalence of diagnosed, undiagnosed, and total diabetes among adults, by race/ethnicity and education. Available at: https://www.cdc.gov/diabetes/php/data-research/appendix.html
#
# <a id="ref7"></a>[7] To KG et al. *Awareness of having hypertension, diabetes and dyslipidaemia among US adults: The 2011–2018 NHANES data.* Scand J Public Health. 2025;53(4):391–399. PubMed: https://pubmed.ncbi.nlm.nih.gov/38679806/
#
# <a id="ref8"></a>[8] Wilder RP, Majumdar SR, Klarenbach SW, Jacobs P. *Socio-economic status and undiagnosed diabetes.* Diabetes Res Clin Pract. 2005;70(1):26–30. PubMed: https://pubmed.ncbi.nlm.nih.gov/16126120/
#
# <a id="ref9"></a>[9] Kim JH et al. *Prevalence and Risk Factors for Undiagnosed Glucose Intolerance Status in Apparently Healthy Young Adults Aged <40 Years: The Korean National Health and Nutrition Examination Survey 2014–2017.* Int J Environ Res Public Health. 2019;16(13):2396. PMC: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6651181/
#
# <a id="ref10"></a>[10] Liu J et al. *Use of Automated Machine Learning to Detect Undiagnosed Diabetes in US Adults: Development and Validation Study.* JMIR AI. 2025;4:e68260. Available at: https://ai.jmir.org/2025/1/e68260
#
# <a id="ref11"></a>[11] Riveros Perez E, Avella-Molano B. *Learning from the machine: is diabetes in adults predicted by lifestyle variables? A retrospective predictive modelling study of NHANES 2007–2018.* BMJ Open. 2025;15(3):e096595. Available at: https://bmjopen.bmj.com/content/15/3/e096595
#
# <a id="ref12"></a>[12] National Center for Health Statistics. *NHANES 2017–2018 Glycohemoglobin (GHB_J) Data Documentation, Codebook, and Frequencies.* Available at: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/GHB_J.htm
#
# <a id="ref13"></a>[13] Fan J, Upadhye S, Worster A. *Understanding receiver operating characteristic (ROC) curves.* CJEM. 2006;8(1):19–20. (See also: *Assessing the Accuracy of Diagnostic Tests* – Table 2 AUC interpretation.) PMC: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6410404/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that, among U.S. adults meeting the biomarker criteria for diabetes in NHANES 2017-2018, being undiagnosed will be less common in those with worse healthcare access. The specific indicators of this include lower income, lack of health insurance status, no consistent source of care, and lack of annual health checkups. Drawing on prior work, we also hypothesize that people of color (such as Black, Hispanic and Asians) will have higher odds of being undiagnosed. With regards to predictive modelling, we hypothesize that models using only non-clinical variables will be able to achieve moderate predictive power, roughly corresponding to an AUC of 0.7. This is due to the success of previous models on similar tasks. Lastly, we hypothesize that predictive performance will differ between different racial/ethnic and income groups.

# %% [markdown]
# ## Data

# %% [markdown]
# **Ideal Dataset**
#
# The ideal dataset would have a large sample size and be nationally representative. In addition, it would contain the following measurements:
#
# *Outcome Data*
# - Laboratory tests indicative of diabetes (hemoglobin A1c and fasting plasma blood glucose)
# - Self-reported history of diabetes diagnosis by a physician
#
# *Predictors and Controls*
# - Demographic: age, sex, race, ethnicity
# - Socioeconomic: household income, employment, education
# - Healthcare access: insurance coverage, typical source of care, time since last routine checkup
# - Lifestyle: smoking, alcohol, exercise
# - Anthropometric: BMI, waist circumference, adiposity
#
# *Overall Dataset Features*
# - Large sample size to allow analysis of subgroups
# - Weighted representation of data from different geographic regions
# - Extensive documentation and codebooks
#
# **Real Dataset**
#
# *NHANES 2017-2018*
#
# The primary dataset for our project is the publicly available files from 2017-2018 NHANES. These are freely available from the CDC website:
# https://wwwn.cdc.gov/nchs/nhanes/Default.aspx
#
# NHANES is a nationally representative survey that interviews, physical exam results, and laboratory test data from the U.S. population. The following files will be used in this project:
# - Demographics – includes age, sex, race, ethnicity, education, income
# - Glycohemoglobin – lab file; includes hemoglobin A1c values
# - Plasma Fasting Glucose – lab file; includes fasting plasma glucose values
# - Individual files under the Questionnaire section that contains insurance, source of care, smoking, alcohol, and exercise
#
# All the above files are de-identified and do not require special permission to download.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
import pandas as pd
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Requirement already satisfied: requests in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (2.32.5)
# Requirement already satisfied: tqdm in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Overall Download Progress:   0%|                                                                 | 0/2 [00:00<?, ?it/s]
# Downloading airline-safety.csv:   0%|                                                      | 0.00/1.23k [00:00<?, ?B/s]
# Overall Download Progress:  50%|████████████████████████████▌                            | 1/2 [00:00<00:00,  5.77it/s]
# Successfully downloaded: airline-safety.csv
# Downloading bad-drivers.csv:   0%|                                                         | 0.00/1.37k [00:00<?, ?B/s]
# Overall Download Progress: 100%|█████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  6.22it/s]
# Successfully downloaded: bad-drivers.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions: REPLACE the contents of this cell and the one below with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
df = pd.read_csv("data/01-interim/nhanes_diabetes.csv")
df.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  93714.0      10.0       2.0       2.0      54.0       NaN       4.0
# 1  93730.0      10.0       2.0       1.0      57.0       NaN       2.0
# 2  93758.0      10.0       2.0       2.0      55.0       NaN       3.0
# 3  93759.0      10.0       2.0       1.0      60.0       NaN       5.0
# 4  93762.0      10.0       2.0       2.0      74.0       NaN       1.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DID310D  DID320  DID330        DID341  \
# 0       4.0       2.0       NaN  ...   6666.0  9999.0  9999.0  5.397605e-79
# 1       2.0       2.0       NaN  ...   6666.0  9999.0  9999.0  2.000000e+00
# 2       3.0       1.0       NaN  ...   6666.0  9999.0  6666.0  5.397605e-79
# 3       7.0       2.0       NaN  ...     80.0    82.0  9999.0  5.397605e-79
# 4       1.0       1.0       NaN  ...   6666.0  9999.0  6666.0  5.397605e-79
#
#          DID350  DIQ350U  DIQ360  DIQ080  diabetes_biomarker  diagnosed
# 0  4.000000e+00      2.0     3.0     2.0                True       True
# 1  1.000000e+00      1.0     5.0     2.0                True       True
# 2  3.000000e+00      2.0     4.0     1.0                True       True
# 3  5.397605e-79      NaN     3.0     2.0                True       True
# 4  5.397605e-79      NaN     2.0     2.0                True       True
#
# [5 rows x 181 columns]

# %%
df.shape
# Out:
# (860, 181)

# %%
df.columns
# Out:
# Index(['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM',
#        ...
#        'DID310D', 'DID320', 'DID330', 'DID341', 'DID350', 'DIQ350U', 'DIQ360',
#        'DIQ080', 'diabetes_biomarker', 'diagnosed'],
#       dtype='object', length=181)

# %%
df.describe()
# Out:
#                 SEQN  SDDSRVYR  RIDSTATR    RIAGENDR    RIDAGEYR  RIDAGEMN  \
# count     860.000000     860.0     860.0  860.000000  860.000000       0.0
# mean    98316.922093      10.0       2.0    1.476744   61.938372       NaN
# std      2719.110226       0.0       0.0    0.499750   12.784856       NaN
# min     93714.000000      10.0       2.0    1.000000   18.000000       NaN
# 25%     95836.250000      10.0       2.0    1.000000   54.000000       NaN
# 50%     98417.000000      10.0       2.0    1.000000   63.000000       NaN
# 75%    100577.250000      10.0       2.0    2.000000   71.000000       NaN
# max    102952.000000      10.0       2.0    2.000000   80.000000       NaN
#
#          RIDRETH1    RIDRETH3    RIDEXMON    RIDEXAGM  ...      DIQ300D  \
# count  860.000000  860.000000  860.000000    3.000000  ...   595.000000
# mean     3.226744    3.470930    1.515116  232.000000  ...  3408.341176
# std      1.304949    1.689615    0.500062    3.605551  ...  4686.628925
# min      1.000000    1.000000    1.000000  228.000000  ...    30.000000
# 25%      2.000000    2.000000    1.000000  230.500000  ...    73.000000
# 50%      3.000000    3.000000    2.000000  233.000000  ...    82.000000
# 75%      4.000000    4.000000    2.000000  234.000000  ...  9999.000000
# max      5.000000    7.000000    2.000000  235.000000  ...  9999.000000
#
#            DID310S      DID310D       DID320       DID330        DID341  \
# count   596.000000   596.000000   595.000000   566.000000  5.940000e+02
# mean   4436.134228  4611.414430  8162.085714  7685.468198  8.662626e+01
# std    4069.495509  4113.148169  3656.413166  3163.144065  9.140654e+02
# min      80.000000    30.000000    30.000000    36.000000  5.397605e-79
# 25%     120.000000    80.000000  9999.000000  6666.000000  1.000000e+00
# 50%    6666.000000  6666.000000  9999.000000  9999.000000  2.000000e+00
# 75%    6666.000000  6666.000000  9999.000000  9999.000000  4.000000e+00
# max    9999.000000  9999.000000  9999.000000  9999.000000  9.999000e+03
#
#              DID350     DIQ350U      DIQ360      DIQ080
# count  5.940000e+02  491.000000  596.000000  596.000000
# mean   1.821549e+01    1.564155    2.538591    1.837248
# std    4.102114e+02    0.819070    1.268965    0.716214
# min    5.397605e-79    1.000000    1.000000    1.000000
# 25%    1.000000e+00    1.000000    2.000000    2.000000
# 50%    1.000000e+00    1.000000    2.000000    2.000000
# 75%    1.000000e+00    2.000000    3.000000    2.000000
# max    9.999000e+03    4.000000    9.000000    9.000000
#
# [8 rows x 177 columns]

# %%
df.isnull().sum()
# Out:
# SEQN                    0
# SDDSRVYR                0
# RIDSTATR                0
# RIAGENDR                0
# RIDAGEYR                0
#                      ...
# DIQ350U               369
# DIQ360                264
# DIQ080                264
# diabetes_biomarker      0
# diagnosed               0
# Length: 181, dtype: int64

# %%
df[['diabetes_biomarker','diagnosed']].value_counts()
# Out:
# diabetes_biomarker  diagnosed
# True                True         597
#                     False        263
# Name: count, dtype: int64

# %%
df['diabetes_biomarker'].mean()
df['diagnosed'].mean()
# Out:
# np.float64(0.6941860465116279)

# %%
#About X% meet biomarker criteria
#About Y% report diagnosis

# %%
[c for c in df.columns if "diabet" in c.lower()]
# Out:
# ['diabetes_biomarker']

# %%
df.columns.tolist()[:20]
# Out:
# ['SEQN',
#  'SDDSRVYR',
#  'RIDSTATR',
#  'RIAGENDR',
#  'RIDAGEYR',
#  'RIDAGEMN',
#  'RIDRETH1',
#  'RIDRETH3',
#  'RIDEXMON',
#  'RIDEXAGM',
#  'DMQMILIZ',
#  'DMQADFC',
#  'DMDBORN4',
#  'DMDCITZN',
#  'DMDYRSUS',
#  'DMDEDUC3',
#  'DMDEDUC2',
#  'DMDMARTL',
#  'RIDEXPRG',
#  'SIALANG']

# %%
undiagnosed_rate = 263 / (597 + 263)
undiagnosed_rate
# Out:
# 0.3058139534883721

# %%
~30% of individuals meeting biomarkers criteria are undiagnosed
# Out:
#   Cell In[228], line 1
#     ~30% of individuals meeting biomarkers criteria are undiagnosed
#             ^
# SyntaxError: invalid syntax

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\alexa\anaconda3\envs\cogs108_fa25\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

sns.countplot(x='diagnosed', data=df)
plt.title('Diagnosed vs Undiagnosed Diabetes')
plt.show()

# %% [markdown]
# ### Dataset #2
#  as above, add any more copies of this that you need to given how many datasets you have

# %%
df['has_diabetes'] = df['diabetes_biomarker'] | df['diagnosed']

# %%
df.groupby('has_diabetes')['RIDAGEYR'].mean()
# Out:
# has_diabetes
# True    61.938372
# Name: RIDAGEYR, dtype: float64

# %%
sns.boxplot(x='has_diabetes', y='RIDAGEYR', data=df)
plt.title("Age vs Diabetes")
plt.show()

# %%
On average, individuals classified as having diabetes tend to be older than those without diabetes. This infers that age is an important risk factor, as the likelihood of diabetes increases with aging.
# Out:
#   Cell In[234], line 1
#     On average, individuals classified as having diabetes tend to be older than those without diabetes. This infers that age is an important risk factor, as the likelihood of diabetes increases with aging.
#        ^
# SyntaxError: invalid syntax

# %%
df.groupby('has_diabetes')['RIAGENDR'].value_counts(normalize=True)
# Out:
# has_diabetes  RIAGENDR
# True          1.0         0.523256
#               2.0         0.476744
# Name: proportion, dtype: float64

# %%
sns.countplot(x='RIAGENDR', hue='has_diabetes', data=df)
plt.title("Gender vs Diabetes")
plt.show()

# %%
Based on this data, the distribution of diabetes is slightly different across gender grops, with one gender showing a higher proportion of diabetes cases. This shows that biological or behvaioral differences between genders may influence diabetes risk.
# Out:
#   Cell In[237], line 1
#     Based on this data, the distribution of diabetes is slightly different across gender grops, with one gender showing a higher proportion of diabetes cases. This shows that biological or behvaioral differences between genders may influence diabetes risk.
#           ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x='RIDRETH3', hue='has_diabetes', data=df)
plt.title("Race vs Diabetes")
plt.show()

# %%
The rate of development of diabetes varies by race and ethnicity. The level of diabetes is significantly higher in some groups than in others, suggesting that socioeconomic status, access to treatment, or genetic factors may be responsible for these differences.
# Out:
#   Cell In[239], line 1
#     The rate of development of diabetes varies by race and ethnicity. The level of diabetes is significantly higher in some groups than in others, suggesting that socioeconomic status, access to treatment, or genetic factors may be responsible for these differences.
#         ^
# SyntaxError: invalid syntax

# %%
sns.boxplot(x='has_diabetes', y='INDFMPIR', data=df)
plt.title("Income vs Diabetes")
plt.show()

# %%
Individuals with diabetes tend to have lower income levels compared to those without diabetes. This suggests a possible relationship between socioeconomic status and diabetes risk, where reduced financial resources may limit access to preventive care, healthy food, or medical support.
# Out:
#   Cell In[241], line 1
#     Individuals with diabetes tend to have lower income levels compared to those without diabetes. This suggests a possible relationship between socioeconomic status and diabetes risk, where reduced financial resources may limit access to preventive care, healthy food, or medical support.
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# Undiagnosed Diabetes Among Biomarker-Positive Individuals
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/01-interim/nhanes_diabetes.csv")

# biomarker-positive only (your analytic sample)
analytic = df[df["diabetes_biomarker"] == True].copy()

# outcome
analytic["undiagnosed"] = analytic["diagnosed"] == False
analytic["diagnosis_status"] = np.where(analytic["undiagnosed"], "Undiagnosed", "Diagnosed")

analytic.shape
# Out:
# (860, 183)

# %%
[c for c in analytic.columns if "WT" in c.upper()]
# Out:
# ['WTINT2YR', 'WTMEC2YR', 'WTSAF2YR']

# %%
W = "WTMEC2YR"
analytic[[W]].head()
# Out:
#         WTMEC2YR
# 0   15479.581198
# 1   28532.938080
# 2   23938.508872
# 3  212848.251291
# 4   26249.586355

# %%
overall = analytic[["diagnosis_status", W]].dropna()

overall_prop = overall.groupby("diagnosis_status")[W].sum()
overall_prop = (overall_prop / overall_prop.sum()).reset_index()
overall_prop = overall_prop.rename(columns={W: "prop"})

overall_prop
# Out:
#   diagnosis_status      prop
# 0        Diagnosed  0.713434
# 1      Undiagnosed  0.286566

# %%
sns.barplot(data=overall_prop, x="diagnosis_status", y="prop")
plt.ylabel("Weighted Proportion")
plt.xlabel("")
plt.title("Weighted % Diagnosed vs Undiagnosed (Biomarker-Positive)")
plt.ylim(0, 1)
plt.show()

# %%
gender = analytic[["RIAGENDR", "diagnosis_status", W]].dropna()

gender_prop = (
    gender.groupby(["RIAGENDR", "diagnosis_status"], as_index=False)[W].sum()
)

# within each gender, convert to proportions
gender_prop["prop"] = gender_prop[W] / gender_prop.groupby("RIAGENDR")[W].transform("sum")

gender_prop
# Out:
#    RIAGENDR diagnosis_status      WTMEC2YR      prop
# 0       1.0        Diagnosed  1.116275e+07  0.757814
# 1       1.0      Undiagnosed  3.567446e+06  0.242186
# 2       2.0        Diagnosed  8.501214e+06  0.662490
# 3       2.0      Undiagnosed  4.330999e+06  0.337510

# %%
# optional: make labels readable
gender_prop["RIAGENDR"] = gender_prop["RIAGENDR"].replace({1: "Male", 2: "Female"})

sns.barplot(data=gender_prop, x="RIAGENDR", y="prop", hue="diagnosis_status")
plt.ylabel("Weighted Proportion within Gender")
plt.xlabel("Gender")
plt.title("Weighted Diagnosis Status by Gender")
plt.ylim(0, 1)
plt.legend(title="")
plt.show()

# %%
race = analytic[["RIDRETH1", "diagnosis_status", W]].dropna()

race_prop = (
    race.groupby(["RIDRETH1", "diagnosis_status"], as_index=False)[W].sum()
)

# convert to within-group proportions
race_prop["prop"] = race_prop[W] / race_prop.groupby("RIDRETH1")[W].transform("sum")

race_prop
# Out:
#    RIDRETH1 diagnosis_status      WTMEC2YR      prop
# 0       1.0        Diagnosed  1.866228e+06  0.672393
# 1       1.0      Undiagnosed  9.092758e+05  0.327607
# 2       2.0        Diagnosed  1.052481e+06  0.611390
# 3       2.0      Undiagnosed  6.689738e+05  0.388610
# 4       3.0        Diagnosed  1.215959e+07  0.761322
# 5       3.0      Undiagnosed  3.812080e+06  0.238678
# 6       4.0        Diagnosed  2.240771e+06  0.587730
# 7       4.0      Undiagnosed  1.571813e+06  0.412270
# 8       5.0        Diagnosed  2.344892e+06  0.714646
# 9       5.0      Undiagnosed  9.363013e+05  0.285354

# %%
# optional: make readable labels
race_prop["RIDRETH1"] = race_prop["RIDRETH1"].replace({
    1: "Mexican American",
    2: "Other Hispanic",
    3: "Non-Hispanic White",
    4: "Non-Hispanic Black",
    5: "Other"
})

sns.barplot(data=race_prop, x="RIDRETH1", y="prop", hue="diagnosis_status")

plt.ylabel("Weighted Proportion within Race/Ethnicity")
plt.xlabel("Race/Ethnicity")
plt.title("Weighted Diagnosis Status by Race/Ethnicity")
plt.ylim(0,1)
plt.xticks(rotation=30)
plt.legend(title="")

plt.show()

# %%
def weighted_quantile(values, weights, q):
    v = np.asarray(values)
    w = np.asarray(weights)
    m = ~(np.isnan(v) | np.isnan(w))
    v, w = v[m], w[m]
    sorter = np.argsort(v)
    v, w = v[sorter], w[sorter]
    cw = np.cumsum(w)
    cutoff = q * cw[-1]
    return v[np.searchsorted(cw, cutoff)]

# %%
age = analytic[["RIDAGEYR", "diagnosis_status", W]].dropna()

age_stats = age.groupby("diagnosis_status").apply(
    lambda x: pd.Series({
        "median": weighted_quantile(x["RIDAGEYR"], x[W], 0.5),
        "Q1": weighted_quantile(x["RIDAGEYR"], x[W], 0.25),
        "Q3": weighted_quantile(x["RIDAGEYR"], x[W], 0.75)
    })
)

age_stats["IQR"] = age_stats["Q3"] - age_stats["Q1"]

age_stats
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_10436\3428568766.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_stats = age.groupby("diagnosis_status").apply(
#                   median    Q1    Q3   IQR
# diagnosis_status
# Diagnosed           62.0  54.0  72.0  18.0
# Undiagnosed         57.0  45.0  67.0  22.0

# %%
sns.boxplot(data=analytic, x="diagnosis_status", y="RIDAGEYR")
plt.title("Age Distribution by Diagnosis Status")
plt.show()

# %%
glu = analytic[["LBXGLU", "diagnosis_status", W]].dropna()

glu_stats = glu.groupby("diagnosis_status").apply(
    lambda x: pd.Series({
        "median": weighted_quantile(x["LBXGLU"], x[W], 0.5),
        "Q1": weighted_quantile(x["LBXGLU"], x[W], 0.25),
        "Q3": weighted_quantile(x["LBXGLU"], x[W], 0.75)
    })
)

glu_stats["IQR"] = glu_stats["Q3"] - glu_stats["Q1"]

glu_stats
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_10436\344078010.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   glu_stats = glu.groupby("diagnosis_status").apply(
#                   median     Q1     Q3   IQR
# diagnosis_status
# Diagnosed          157.0  131.0  200.0  69.0
# Undiagnosed        134.0  127.0  147.0  20.0

# %%
sns.boxplot(data=analytic, x="diagnosis_status", y="LBXGLU")
plt.title("Fasting Glucose Distribution by Diagnosis Status")
plt.show()

# %%
race_undiag = analytic[["RIDRETH1", "undiagnosed", W]].dropna()

race_undiag_prop = (
    race_undiag.groupby(["RIDRETH1", "undiagnosed"], as_index=False)[W].sum()
)

race_undiag_prop["prop"] = race_undiag_prop[W] / race_undiag_prop.groupby("RIDRETH1")[W].transform("sum")

# keep only undiagnosed rows
race_undiag_only = race_undiag_prop[race_undiag_prop["undiagnosed"] == True]

race_undiag_only
# Out:
#    RIDRETH1  undiagnosed      WTMEC2YR      prop
# 1       1.0         True  9.092758e+05  0.327607
# 3       2.0         True  6.689738e+05  0.388610
# 5       3.0         True  3.812080e+06  0.238678
# 7       4.0         True  1.571813e+06  0.412270
# 9       5.0         True  9.363013e+05  0.285354

# %%
race_undiag_only["RIDRETH1"] = race_undiag_only["RIDRETH1"].replace({
    1: "Mexican American",
    2: "Other Hispanic",
    3: "Non-Hispanic White",
    4: "Non-Hispanic Black",
    5: "Other"
})

sns.barplot(data=race_undiag_only, x="RIDRETH1", y="prop")

plt.ylabel("Weighted % Undiagnosed")
plt.xlabel("Race/Ethnicity")
plt.title("Weighted % Undiagnosed by Race/Ethnicity")
plt.ylim(0,1)
plt.xticks(rotation=30)

plt.show()
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_10436\2675773761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   race_undiag_only["RIDRETH1"] = race_undiag_only["RIDRETH1"].replace({

# %%
gender_undiag = analytic[["RIAGENDR", "undiagnosed", W]].dropna()

gender_undiag_prop = (
    gender_undiag.groupby(["RIAGENDR", "undiagnosed"], as_index=False)[W].sum()
)

gender_undiag_prop["prop"] = gender_undiag_prop[W] / gender_undiag_prop.groupby("RIAGENDR")[W].transform("sum")

# keep only undiagnosed
gender_undiag_only = gender_undiag_prop[gender_undiag_prop["undiagnosed"] == True]

gender_undiag_only
# Out:
#    RIAGENDR  undiagnosed      WTMEC2YR      prop
# 1       1.0         True  3.567446e+06  0.242186
# 3       2.0         True  4.330999e+06  0.337510

# %%
gender_undiag_only["RIAGENDR"] = gender_undiag_only["RIAGENDR"].replace({
    1: "Male",
    2: "Female"
})

sns.barplot(data=gender_undiag_only, x="RIAGENDR", y="prop")

plt.ylabel("Weighted % Undiagnosed")
plt.xlabel("Gender")
plt.title("Weighted % Undiagnosed by Gender")
plt.ylim(0,1)

plt.show()
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_10436\1636813305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_undiag_only["RIAGENDR"] = gender_undiag_only["RIAGENDR"].replace({

# %%
missing = analytic.isna().mean() * 100
missing = missing.sort_values(ascending=False)

missing
# Out:
# RIDAGEMN              100.0
# SMQ661                100.0
# SMQ665A               100.0
# SMQ621                100.0
# SMD630                100.0
#                       ...
# DIQ050                  0.0
# diabetes_biomarker      0.0
# diagnosed               0.0
# undiagnosed             0.0
# diagnosis_status        0.0
# Length: 183, dtype: float64

# %%
missing.plot(kind="bar", figsize=(12,5))

plt.ylabel("% Missing")
plt.title("Percent Missing by Variable")

plt.show()

# %%
import seaborn as sns

sns.heatmap(analytic.isna(), cbar=False)

plt.title("Missingness Pattern Heatmap")
plt.show()

# %% [markdown]
# Some of the survey-based variables have a noticeable amount of missing data, especially questions related to personal behaviors and access to healthcare. This is expected since not everyone answers every survey question. In comparison, key clinical measurements like age and fasting glucose are mostly complete across participants. This is helpful because it means our main health-related variables are reliable for comparing diagnosed and undiagnosed individuals. Overall, while some background information is missing for certain people, the core medical data needed for this analysis is available and usable.

# %% [markdown]
# #### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import pandas as pd
import matplotlib.pyplot as plt

if "diagnosis_label" not in analytic.columns:
    analytic["diagnosis_label"] = analytic["undiagnosed"].map({
        True: "Undiagnosed",
        False: "Diagnosed"
    })

analytic["race"] = analytic["RIDRETH3"].map({
    1: "Mexican American",
    2: "Other Hispanic",
    3: "Non-Hispanic White",
    4: "Non-Hispanic Black",
    6: "Non-Hispanic Asian",
    7: "Other"
})

analytic["sex"] = analytic["RIAGENDR"].map({1: "Male", 2: "Female"})
analytic["insurance"] = analytic["HIQ011"].map({1: "Insured", 2: "Uninsured"})
analytic["education"] = analytic["DMDEDUC2"].map({
    1: "<9th Grade",
    2: "9–11th Grade",
    3: "High School/GED",
    4: "Some College/AA",
    5: "College Graduate"
})
analytic["income_cat"] = pd.cut(
    analytic["INDFMPIR"],
    bins=[0, 1, 2, analytic["INDFMPIR"].max()],
    labels=["Low (<1)", "Middle (1–2)", "High (2+)"]
)

# Health / behavior
if "SMQ020" in analytic.columns:
    analytic["smoking"] = analytic["SMQ020"].map({1: "Smoker", 2: "Non-Smoker"})

if "ALQ111" in analytic.columns:
    analytic["alcohol"] = analytic["ALQ111"].map({1: "Drinker", 2: "Non-Drinker"})

if "PAQ650" in analytic.columns:
    analytic["exercise"] = analytic["PAQ650"].map({1: "Exercises", 2: "No Exercise"})

predictors = ["race", "sex", "insurance", "education", "income_cat"]

for var in ["smoking", "alcohol", "exercise"]:
    if var in analytic.columns:
        predictors.append(var)

title_map = {var: var.replace("_", " ").capitalize() for var in predictors}

fig, axes = plt.subplots((len(predictors)+1)//2, 2, figsize=(14, 5*((len(predictors)+1)//2)))
axes = axes.flatten()

for i, var in enumerate(predictors):
   
    df = analytic[[var, "diagnosis_label", "WTMEC2YR"]].dropna()
    
    weighted = df.groupby([var, "diagnosis_label"])["WTMEC2YR"].sum().reset_index()
    
    table = weighted.pivot(index=var, columns="diagnosis_label", values="WTMEC2YR")
    
    if table.empty:
        axes[i].axis("off")
        continue
    
    table = table.astype(float)
    
    row_percent = table.div(table.sum(axis=1), axis=0) * 100
    
    print(f"\nWeighted % by {title_map[var]}")
    display(row_percent.round(1))
    
    row_percent.plot(
        kind="bar",
        stacked=True,
        ax=axes[i],
        color=["#4C72B0", "#DD8452"],
        legend=False
    )
    
    axes[i].set_title(title_map[var])
    axes[i].set_ylim(0, 100)
    axes[i].set_ylabel("Percent")
    axes[i].tick_params(axis='x', rotation=45)

for j in range(i+1, len(axes)):
    axes[j].axis("off")

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")

plt.tight_layout()
plt.show()
# Out:
# Weighted % by Race
# diagnosis_label     Diagnosed  Undiagnosed
# race
# Mexican American         67.2         32.8
# Non-Hispanic Asian       63.5         36.5
# Non-Hispanic Black       58.8         41.2
# Non-Hispanic White       76.1         23.9
# Other                    83.2         16.8
# Other Hispanic           61.1         38.9
# Weighted % by Sex
# diagnosis_label  Diagnosed  Undiagnosed
# sex
# Female                66.2         33.8
# Male                  75.8         24.2
# Weighted % by Insurance
# diagnosis_label  Diagnosed  Undiagnosed
# insurance
# Insured               72.9         27.1
# Uninsured             58.3         41.7
# Weighted % by Education
# diagnosis_label   Diagnosed  Undiagnosed
# education
# 9–11th Grade           71.8         28.2
# <9th Grade             66.8         33.2
# College Graduate       66.1         33.9
# High School/GED        73.8         26.2
# Some College/AA        74.9         25.1
# Weighted % by Income cat
# C:\Users\alexa\AppData\Local\Temp\ipykernel_10436\2337363094.py:59: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weighted = df.groupby([var, "diagnosis_label"])["WTMEC2YR"].sum().reset_index()
# diagnosis_label  Diagnosed  Undiagnosed
# income_cat
# Low (<1)              69.7         30.3
# Middle (1–2)          66.8         33.2
# High (2+)             73.0         27.0
# Weighted % by Smoking
# diagnosis_label  Diagnosed  Undiagnosed
# smoking
# Non-Smoker            65.6         34.4
# Smoker                77.4         22.6
# Weighted % by Alcohol
# diagnosis_label  Diagnosed  Undiagnosed
# alcohol
# Drinker               70.4         29.6
# Non-Drinker           76.1         23.9
# Weighted % by Exercise
# diagnosis_label  Diagnosed  Undiagnosed
# exercise
# Exercises             57.1         42.9
# No Exercise           73.3         26.7

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
